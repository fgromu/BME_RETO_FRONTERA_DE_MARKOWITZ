# %% [markdown]
# SECCION 1

# %%
import time
start = time.process_time()

#PREPARO LAS BASES DEL PROGRAMA
#A. Import the os module
import os
os.getcwd()
# Change the current working directory
os.chdir('C:\\Users\\Lenovo\\anaconda3\\Programando')


os.getcwd()

#B. Cargar toda las librerias que estoy usando
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from datetime import timedelta
import random
from datetime import datetime

#C.Descargo todos los ficheros csv con fondos
df_0 = pd.read_csv('0.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_0.index = pd.to_datetime(df_0.date)

df_1 = pd.read_csv('1.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_1.index = pd.to_datetime(df_1.date)

df_2 = pd.read_csv('2.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_2.index = pd.to_datetime(df_2.date)

df_3 = pd.read_csv('3.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_3.index = pd.to_datetime(df_3.date)

df_4 = pd.read_csv('4.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_4.index = pd.to_datetime(df_4.date)

df_5 = pd.read_csv('5.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_5.index = pd.to_datetime(df_5.date)

df_6 = pd.read_csv('6.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_6.index = pd.to_datetime(df_6.date)

df_7 = pd.read_csv('7.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_7.index = pd.to_datetime(df_7.date)

df_8 = pd.read_csv('8.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_8.index = pd.to_datetime(df_8.date)

df_9 = pd.read_csv('9.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_9.index = pd.to_datetime(df_9.date)

df_10 = pd.read_csv('10.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_10.index = pd.to_datetime(df_10.date)

df_11 = pd.read_csv('11.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_11.index = pd.to_datetime(df_11.date)

df_12 = pd.read_csv('12.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_12.index = pd.to_datetime(df_12.date)

df_13 = pd.read_csv('13.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_13.index = pd.to_datetime(df_13.date)

df_14 = pd.read_csv('14.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_14.index = pd.to_datetime(df_14.date)

df_15 = pd.read_csv('15.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_15.index = pd.to_datetime(df_15.date)

df_16 = pd.read_csv('16.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_16.index = pd.to_datetime(df_16.date)

df_17 = pd.read_csv('17.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_17.index = pd.to_datetime(df_17.date)

df_18 = pd.read_csv('18.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_18.index = pd.to_datetime(df_18.date)

df_19 = pd.read_csv('19.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_19.index = pd.to_datetime(df_19.date)

df_20 = pd.read_csv('20.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_20.index = pd.to_datetime(df_20.date)

df_21 = pd.read_csv('21.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_21.index = pd.to_datetime(df_21.date)

df_22 = pd.read_csv('22.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_22.index = pd.to_datetime(df_22.date)

df_23 = pd.read_csv('23.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_23.index = pd.to_datetime(df_23.date)

df_24 = pd.read_csv('24.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_24.index = pd.to_datetime(df_24.date)

df_25 = pd.read_csv('25.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_25.index = pd.to_datetime(df_25.date)

df_26 = pd.read_csv('26.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_26.index = pd.to_datetime(df_26.date)

df_27 = pd.read_csv('27.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_27.index = pd.to_datetime(df_27.date)

df_28 = pd.read_csv('28.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_28.index = pd.to_datetime(df_28.date)

df_29 = pd.read_csv('29.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_29.index = pd.to_datetime(df_29.date)

df_30 = pd.read_csv('30.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_30.index = pd.to_datetime(df_30.date)

df_31 = pd.read_csv('31.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_31.index = pd.to_datetime(df_31.date)

df_32 = pd.read_csv('32.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_32.index = pd.to_datetime(df_32.date)

df_33 = pd.read_csv('33.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_33.index = pd.to_datetime(df_33.date)

df_34 = pd.read_csv('34.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_34.index = pd.to_datetime(df_34.date)

df_35 = pd.read_csv('35.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_35.index = pd.to_datetime(df_35.date)

df_36 = pd.read_csv('36.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_36.index = pd.to_datetime(df_36.date)

df_37 = pd.read_csv('37.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_37.index = pd.to_datetime(df_37.date)

df_38 = pd.read_csv('38.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_38.index = pd.to_datetime(df_38.date)

df_39 = pd.read_csv('39.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_39.index = pd.to_datetime(df_39.date)

df_40 = pd.read_csv('40.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_40.index = pd.to_datetime(df_40.date)

df_41 = pd.read_csv('41.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_41.index = pd.to_datetime(df_41.date)

df_42 = pd.read_csv('42.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_42.index = pd.to_datetime(df_42.date)

df_43 = pd.read_csv('43.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_43.index = pd.to_datetime(df_43.date)

df_44 = pd.read_csv('44.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_44.index = pd.to_datetime(df_44.date)

df_45 = pd.read_csv('45.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_45.index = pd.to_datetime(df_45.date)

df_46 = pd.read_csv('46.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_46.index = pd.to_datetime(df_46.date)

df_47 = pd.read_csv('47.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_47.index = pd.to_datetime(df_47.date)

df_48 = pd.read_csv('48.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_48.index = pd.to_datetime(df_48.date)

df_49 = pd.read_csv('49.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_49.index = pd.to_datetime(df_49.date)

df_50 = pd.read_csv('50.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_50.index = pd.to_datetime(df_50.date)

df_51 = pd.read_csv('51.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_51.index = pd.to_datetime(df_51.date)

df_52 = pd.read_csv('52.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_52.index = pd.to_datetime(df_52.date)

df_53 = pd.read_csv('53.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_53.index = pd.to_datetime(df_53.date)

df_54 = pd.read_csv('54.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_54.index = pd.to_datetime(df_54.date)

df_55 = pd.read_csv('55.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_55.index = pd.to_datetime(df_55.date)

df_56 = pd.read_csv('56.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_56.index = pd.to_datetime(df_56.date)

df_57 = pd.read_csv('57.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_57.index = pd.to_datetime(df_57.date)

df_58 = pd.read_csv('58.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_58.index = pd.to_datetime(df_58.date)

df_59 = pd.read_csv('59.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_59.index = pd.to_datetime(df_59.date)

df_60 = pd.read_csv('60.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_60.index = pd.to_datetime(df_60.date)

df_61 = pd.read_csv('61.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_61.index = pd.to_datetime(df_61.date)

df_62 = pd.read_csv('62.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_62.index = pd.to_datetime(df_62.date)

df_63 = pd.read_csv('63.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_63.index = pd.to_datetime(df_63.date)

df_64 = pd.read_csv('64.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_64.index = pd.to_datetime(df_64.date)

df_65 = pd.read_csv('65.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_65.index = pd.to_datetime(df_65.date)

df_66 = pd.read_csv('66.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_66.index = pd.to_datetime(df_66.date)

df_67 = pd.read_csv('67.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_67.index = pd.to_datetime(df_67.date)

df_68 = pd.read_csv('68.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_68.index = pd.to_datetime(df_68.date)

df_69 = pd.read_csv('69.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_69.index = pd.to_datetime(df_69.date)

df_70 = pd.read_csv('70.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_70.index = pd.to_datetime(df_70.date)

#D.Monto en un df todos los ficheros descargados antes en df por fichero
df_final = pd.concat([df_0,df_1,df_2,df_3,df_4,df_5,df_6,df_7,df_8,df_9,
                     df_10,df_11,df_12,df_13,df_14,df_15,df_16,df_17,df_18,df_19,
                     df_20,df_21,df_22,df_23,df_24,df_25,df_26,df_27,df_28,df_29,
                     df_30,df_31,df_32,df_33,df_34,df_35,df_36,df_37,df_38,df_39,
                     df_40,df_41,df_42,df_43,df_44,df_45,df_46,df_47,df_48,df_49,
                     df_50,df_51,df_52,df_53,df_54,df_55,df_56,df_57,df_58,df_59,
                     df_60,df_61,df_62,df_63,df_64,df_65,df_66,df_67,df_68,df_69,df_70])

print("This time is being calculated")
end = time.process_time()
print(end - start)
# Out:
# This time is being calculated
# 24.84375

# %%
start = time.process_time()

#Mejora 1
#Estudio de df_final para eliminar fondos y dias
#Mejora #¿Con cuántos activos nos quedamos y por qué? 
#Punto M.1 Eliminar fondos que tienen muy pocos valores.

#propongo eliminar todos los fondos que tengan un numero de dias inferior al quantile 65%.
# Se eliminarian 126057 fondos de un total original de 193678 fondos
#He llegado a esta conclusion al analizar el resultado segun los siguiente
fondos_por_dias_cotizados=df_final.loc[:,['date','name']].groupby('name').count()
p2=[]
for i in np.arange(0, 1, 0.01):    
    p2.extend(list(fondos_por_dias_cotizados.quantile(q=i)))
p2_df = pd.DataFrame(p2,index=np.arange(0, 1, 0.01))
p2_df.plot()
plt.xlabel('quantiles de dias con fondos')
plt.ylabel('numero de fondos')


a= list(fondos_por_dias_cotizados.quantile(q=0.65))
fondos_a_eliminar= fondos_por_dias_cotizados.index[fondos_por_dias_cotizados.date <= a[0]]
salvar_fondos=set(list(fondos_por_dias_cotizados.index)).difference(set(list(fondos_a_eliminar)))
df_final_2=df_final[df_final.name.isin(salvar_fondos)]


print('Total fondos descargados de 0 a 70.csv es de ',fondos_por_dias_cotizados.shape)
print('Total fondos que se deben eliminar que tienen un solo dias cotizados ',fondos_a_eliminar.shape)
print('El nombre de los fondos a eliminar estan en la variable fondos_a_eliminar')
print('Total fondos que no eliminaria pq tiene muchos dias cotizados ',len(salvar_fondos))


print("This time is being calculated")
end = time.process_time()
print(end - start)
# Out:
# Total fondos descargados de 0 a 70.csv es de  (193678, 1)
# Total fondos que se deben eliminar que tienen un solo dias cotizados  (126057,)
# El nombre de los fondos a eliminar estan en la variable fondos_a_eliminar
# Total fondos que no eliminaria pq tiene muchos dias cotizados  67621
# This time is being calculated
# 8.171875

# %%
start = time.process_time()

#Mejora 2

#Punto M.2 Eliminar dias que tienen muy pocos valores.
# Respecto a la pregunta: Hay días en los que la mayoría de los activos no tienen cotización ¿qué hacemos?

# Si repito el mismo ejercicio que la celda anterior pero respecto a los dias con pocos fondos cotizados, entonces me sale
df_final_3 = df_final_2
df_final_3 = df_final_3 .rename(columns={'date': 'date_1'})
dias_con_valores=df_final_3.loc[:,['date_1','name']].groupby('date_1').count()
#p=dias_con_valores.name.sort_values(ascending=True)
#p.plot.hist()

p2=[]
for i in np.arange(0, 1, 0.01):    
    p2.extend(list(dias_con_valores.quantile(q=i)))
p2_df = pd.DataFrame(p2,index=np.arange(0, 1, 0.01))
p2_df.plot()
plt.xlabel('quantiles de dias con fondos')
plt.ylabel('numero de fondos')


# En este caso; como se ve en las graficas, se podria quitar los que no alcanzaran el quantil 20%.
# Con este valor, quito los dias que afectan a solo 344 fondos de los 57945 que me quedanban de 
# la primera mejor. Todavia me quedaria con 274 dias para estudio.

b= list(dias_con_valores.quantile(q=0.20))
dias_a_eliminar= dias_con_valores.index[dias_con_valores.name <= b[0]]
print(dias_a_eliminar.shape)
# que me sale a eliminar 70 dias.
# Se que esto no lo deberia hacer si tubiera un buen ordenador ya que el profesor ha dicho varias veces de eliminar
# menos numero de dias posible y es mejor rellenarlos con el valor posterior o si no el anterior dando unas 
# rentabilidades a 0 en esos dias. Pero en este caso los elimino pq es un reto.

# Elimino las dias que tengan name como los que me han salido en dias_con_valores_eliminar
# Y me quedo con el df_final_3

#salvar_dias=set(list(dias_con_valores.index)).difference(set(list(dias_con_valores_eliminar)))
salvar_dias=set(list(dias_con_valores.index)).difference(set(list(dias_a_eliminar)))
len(salvar_dias)
df_final_3=df_final_3[df_final_3.date_1.isin(salvar_dias)]
df_final_3 = df_final_3 .rename(columns={'date_1': 'date'})


print("This time is being calculated")
end = time.process_time()
print(end - start)
# Out:
# (71,)
# This time is being calculated
# 7.640625

# %%
#EMPIEZO CON EL PROGRAMA con los fondos ya preseleccionados con las mejoras 1 y 2
start = time.process_time()
df_0 = df_final_3 # esta linea la tengo para no fastidiar el programa que me iba con solo df_0


#1.creo el df para empezar para guardar los close de los fondos
import datetime
# Un dia en clase se dijo que habia fondos que cotizaban los fines de semana. 
# Pero creo que serian los minimos. Asi que mantengo freq=B y no pongo 'D' = diario
dates = pd.date_range('2020-1-1', '2020-12-31', freq='B') 
df_act = pd.DataFrame(np.zeros((dates.shape[0])),index = dates)
df_act = df_act.iloc[:,1:df_act.shape[1]]#Elimino la primera columna de ceros. Asi solo eta el indice

#HOMOGENIZACION
#Los activos no tienen los mismos días cotizados, ¿cómo los homogeneizamos?
#Esto lo resuelvo con mejora 1 y 2 y con la forma de crear df_act


#2.miro cuantos fondos tiene el df con el que voy a trabajar 
n_e_df_final = list(set(df_0.loc[:,'name']))
#len(n_e_df_final)
# y me salen 67621 fondos. Mas o menos lo esperado

#3 relleno el df por fondo y hago merge por dia 
# En el enunciado dice: El número de activos de cada cartera generada debe ser diferente... 
# saco un aleatorio que me diga que numero de fondos voy a analizar como sigue.
# Como hemos visto en clase que el max es 30; y ya es demasiado, que haga hasta 20 el
# numero de fondos a estudiar. Ya he visto testeando y testeando que mas de 12, la curva no sale
# He visto que con 2 y 3 fondos solo hace cosas raras. Asi que he puesto rangos de 4 a 12.

n_fondos = np.random.randint(4,12)
print('Numero de fondos es ',n_fondos)

# y los fondos que seran se eligen aleatoriamente asi:
fondos_posicion = list(np.random.randint(1,len(n_e_df_final),n_fondos))
fondos_estudio =[]
df_aux_2 = pd.DataFrame()

for i in fondos_posicion:
    #fondos_estudio.append(n_e_df_final[i])
    df_aux_2 = df_0[df_0.loc[:,'name'] == n_e_df_final[i]]
    df_act = df_act.merge(df_aux_2.loc[:,'nav'], how='outer', left_index=True, right_index=True)
    df_act.rename(columns = {'nav':n_e_df_final[i]}, inplace = True)

#df_act.shape





# LIMPIEZA DE NANS SI HUBIERA

#4. miro los nan de los fondos
cuantos_nan = df_act.isna().sum()
menos_nan = min(df_act.isna().sum())
cuantos_nan_ord = cuantos_nan.sort_values()
#print(cuantos_nan)
#print(menos_nan)
#print(cuantos_nan_ord)
# me salen solo algunos nan en 6 fondos. Los pordria eliminar, pero como tambien tienen un gran numero de valores,
# pues los dejo y que se rellenen mas tarde con el fillna



#5  El cinco no es necesario si quito los nan en el df de trabajo

#6 dropna para eliminar cuando toda la fila en nan ya que hay fondos tan importantes que seguro que trabajaban
#todos los dias menos los festivos, pq me salia qu esolo 18 dias estaban de sobra 
df_act_2 = df_act.dropna(how='all')

#df_act_2

# RELLENAR LOS NAN QUE PARECE LOGUICOS QUE TENGAMOS
#7 Relleno los nan que falta poniendo el del dia siquiente (como primera opcion) o el del dia anterior
df_act_2 = df_act_2.fillna(method='ffill')
df_act_2 = df_act_2.fillna(method='bfill')


#AQUI TERMINAMOS LA HOMOGENIZACION Y COMPLETAR LOS NAN TENIENDO LAS CONCLUSIONES EN df_act_2
#df_act_2

#EMPEZAMOS EL PROGRAMA SEGUN LO INDICADO POR Reto Markowitz

#8.Calculamos la rentabilidad de los activos.
df_rent_act = np.log(df_act_2).diff() # como estan en los apuntes del profesor
df_rent_act = df_rent_act.iloc[1:,:] # le quito la primera fila como dice en apuntes de r
df_rent_act

#9. Calculamos la matriz de correlacion del df de rentabilidades de los activos 

corr_df = df_rent_act.corr()
corr_df.fillna(0, inplace=True) # aveces me ha salido un fondo sin dias que el corr era nan; cuando testeaba. Por si acaso, que me lo cambie a 0

#10. Calculamos la matriz de varianzas/covarianzas 
cov_df = df_rent_act.cov()
cov_df.fillna(0, inplace=True)



#11. Calculamos la rentabilidad diaria del periodo para cada activo: LN(precio final/ precio inicial)/nº de datos
rentabilidad = np.log(df_act_2.iloc[df_act_2.shape[0]-1,:]/df_act_2.iloc[0,:])/df_act_2.shape[0]  

#12 Sacamos la matriz de pesos para cada cartera
num_simulaciones = 50000 
print('Numero de simulaciones es ',num_simulaciones) 

# Como se podria bajar el numero de simulacion?
# Los metodos estudiados para que las simulaciones sean mas efectivas hasta ahora serian:
# - Montecarlo
# - Bootstrapping simple
# - Mencionado en clase el Bootstrapping saltando entre periodos
# - Random porfolio
# Entiendo que al usar otro que no seal el Random, no seria necesiario usar 50000 simulaciones

# Usare el Random porfolio ahora. Pero voy a dejar el Montecarlo preparado para usarlo tambien si se quiere.


# El profesor ha pedido
#- No todos los activos pueden tener asignado un peso en la generación aleatoria
# ¿Cómo generamos los números aleatorios y cuantos generamos? 

#METODO RAMDOM PARA CALCULAR PESOS
# Veo dos metodos. Primero genero facilemnte todos los numero aleatorios y los cargo en df de pesos a la vez. 
# Y luego pongo ceros para los que me den en el segundo grupo de aleatorios que no los quiero. 
pesos_df = pd.DataFrame(np.random.uniform(low=0,high=100,size=(num_simulaciones,df_act_2.shape[1])))
pesos_df.columns = df_act_2.columns

ceros_por_simulacion = []

num_de_fondos = df_act_2.shape[1] 
for j in range(0,num_simulaciones-1):
    ceros_por_simulacion = random.randint(0, num_de_fondos-1)
    for i in range(ceros_por_simulacion):
        a = random.randint(0, num_de_fondos-1)
        pesos_df.iloc[j,a] = 0 ############################################################################################
        ceros=ceros+1
porcentaje_ceros = (ceros/(pesos_df.shape[0]*pesos_df.shape[1]))*100
print('Numero de ceros puestos es en %: ',porcentaje_ceros)
#Y una segunda forma es linealmente. Es decir que primero se busca la poscion como antes bscaba la posicion 
# de los ceros; y luego cargo el valor np.random.uniform(low=0,high=100.5)

#¿Cuántos activos seleccionamos en cada simulación para darles peso?, ¿Cómo los seleccionamos?
# Esto esta respondido en este punto, mas arriba. En la variable; ceros_por_simulacion; por cada for 
# es el numero por cada simulacion



# Esta parte de generar pesos se podria mejorar el rendimiento con multiprocessing dividiendo el df pesos_df.
#Guillermo me HA dicho por email que Python no va muy bien con el multipocesing pero se podria intentar con mas tiempo.
# Seria algo asi
#import multiprocessing as mp 
#pool = mp.Pool(mp.cpu_count()-1)
#def funct_to_paral(param): 
    # aqui seria lo que tengo programado en esta celda arriba
#    return pesos_df
#pesos_df = pool.map(funct_to_paral, pesos_df) 
#print(results)

#13. Hacemos que la suma de todos los pesos por simulacion (por fila) sumen 1
#Normalizamos para que sume 1, para cada día
pesos_df = pesos_df.div(pesos_df.sum(1), axis=0) 


#14. Calculamos la rentabilidad de la cartera en funcion de los pesos
aux = pesos_df.T.mul(rentabilidad, axis = 0)

#15.Sumamos las filas para sacar rentabilidad de cada cartera.
#matriz_intermedia = aux.T
#matriz_intermedia.columns = df_act_2.columns
#rentabilidad_carteras = matriz_intermedia.sum(axis=1)
rentabilidad_carteras=aux.sum(axis=0)

#16. Calculamos el riesgo de la cartera (desviación), en función de los pesos.
# Generamos un vector donde guardaremos el riesgo de cada cartera.
riesgo_carteras = [] 
# Ahora multiplicamos la matriz de var/covar por cada fila de la matriz de pesos.
matriz_intermedia = pesos_df.iloc[0:num_simulaciones,]@cov_df
# Ahora multiplicamos cada fila de la matriz intermedia * cada fila de la matriz pesos y el rdo lo elevamos a 0.5. 
  # Ojo, la multiplicación es matricial de dos vectores.
matriz_intermedia_2 = matriz_intermedia * pesos_df
riesgo_carteras = matriz_intermedia_2.sum(axis=1)
riesgo_carteras = riesgo_carteras**0.5

#17. calculamos la eficiencia de la cartera (pendiente), en función de los pesos.
#eficiencia_carteras = []
eficiencia_carteras =  rentabilidad_carteras/riesgo_carteras


#18 # Graficamos la frontera de Markowitz (riesgo y rentabilidad para cada vector de pesos)

data=pd.concat([rentabilidad_carteras,riesgo_carteras],axis=1)
data.columns=['rentabilidad_carteras','riesgo_carteras']
fig, ax = plt.subplots(figsize=(20,10)) 
plt.scatter(data['riesgo_carteras'], data['rentabilidad_carteras'], color='black')

#plt.set_title('Reto Markowitz, para num.activos ',n_fondos, 'y con num.simulaciones ',num_simulaciones)
titulo = 'Reto Markowitz, para num.activos', n_fondos, ',con num.simulaciones ',num_simulaciones,' y con un porcentaje de ceros de ',porcentaje_ceros,'%'
plt.title(titulo)
plt.grid(True,color = 'w',linestyle = ':')
plt.xlabel('riesgo_carteras')
plt.ylabel('rentabilidad_carteras')

data_riesgo_carteras_2d=round(data['riesgo_carteras'],4)
lista = set(data_riesgo_carteras_2d)
riesgo_lista=list()
rent_max_lista=list()

for i in range(1,len(lista)):
    riesgo = lista.pop()    
    riesgo_lista.append(riesgo)
    rent_max=max(data['rentabilidad_carteras'][data_riesgo_carteras_2d==riesgo])
    rent_max_lista.append(rent_max)

rent_max_series=pd.Series(rent_max_lista)
riesgo_lista_series=pd.Series(riesgo_lista)

data_2=pd.concat([rent_max_series,riesgo_lista_series],axis=1)
data_2.columns=['rent_max_series','riesgo_lista_series']

elimina=list()
for i in range(1,data_2.shape[0]-1):
    if data_2['rent_max_series'][i]>data_2['rent_max_series'][i-1]:
        elimina.append(i)
        
# Aveces este programita solo para dibujar bien los puntso de la curva de Markowitz me da error
# a que los valores de riesgo esten entre min_riesgo['riesgo_cartera'] y max_rentabilidad['riesgo_cartera']


#try: 
data_2 = data_2[~(data_2.index.isin(elimina))]
#Y se deberria liitar a 
plt.scatter(data_2['riesgo_lista_series'], data_2['rent_max_series'], color='y')
#except AttributeError:
#    print('Esta vez no se ha cargado la curva de Markowitz') 

# 19 Localizamos la cartera con mayor rentabilidad, menor riesgo y mayor eficiencia
pesos_df.insert(pesos_df.shape[1],"rentabilidad_cartera",rentabilidad_carteras,True)
pesos_df.insert(pesos_df.shape[1],"riesgo_cartera",riesgo_carteras,True)
pesos_df.insert(pesos_df.shape[1],"eficiencia_cartera",eficiencia_carteras,True)

max_rentabilidad = pesos_df[pesos_df.loc[:,'rentabilidad_cartera'] == max(pesos_df.loc[:,'rentabilidad_cartera'])]
min_riesgo = pesos_df[pesos_df.loc[:,'riesgo_cartera'] == min(pesos_df.loc[:,'riesgo_cartera'])]
max_eficiencia = pesos_df[pesos_df.loc[:,'eficiencia_cartera'] == max(pesos_df.loc[:,'eficiencia_cartera'])]

plt.scatter(max_rentabilidad['riesgo_cartera'], max_rentabilidad['rentabilidad_cartera'], color='r')
plt.scatter(min_riesgo['riesgo_cartera'], min_riesgo['rentabilidad_cartera'], color='r')


print("This time is being calculated")

end = time.process_time()
print(end - start)
# Out:
# Numero de fondos es  10
# Numero de simulaciones es  50000
# Numero de ceros puestos es en %:  45.1462
# This time is being calculated
# 25.203125

# %% [markdown]
# SECCION 2

# %%
#Y AQUI AL FINAL EL PROGRAMA COMPLETO PARA VER EL TIEMPO TOTAL DE EJECUCION
# PARA UN NUMERO DE FONDOS DE 4 A 12, 50000 SIMULACIONES Y  CON UNOS PESOS A LOS FONDOS 
# QUE POR SIMULACION SON ALEATORIOS Y EN TODOS LOS CASOS EN ALGUNO EL PESO ES 0.



import time
start = time.process_time()

#PREPARO LAS BASES DEL PROGRAMA
#A. Import the os module
import os
os.getcwd()
# Change the current working directory
os.chdir('C:\\Users\\Lenovo\\anaconda3\\Programando')


os.getcwd()

#B. Cargar toda las librerias que estoy usando
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from datetime import timedelta
import random
from datetime import datetime

#C.Descargo todos los ficheros csv con fondos
df_0 = pd.read_csv('0.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_0.index = pd.to_datetime(df_0.date)

df_1 = pd.read_csv('1.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_1.index = pd.to_datetime(df_1.date)

df_2 = pd.read_csv('2.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_2.index = pd.to_datetime(df_2.date)

df_3 = pd.read_csv('3.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_3.index = pd.to_datetime(df_3.date)

df_4 = pd.read_csv('4.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_4.index = pd.to_datetime(df_4.date)

df_5 = pd.read_csv('5.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_5.index = pd.to_datetime(df_5.date)

df_6 = pd.read_csv('6.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_6.index = pd.to_datetime(df_6.date)

df_7 = pd.read_csv('7.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_7.index = pd.to_datetime(df_7.date)

df_8 = pd.read_csv('8.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_8.index = pd.to_datetime(df_8.date)

df_9 = pd.read_csv('9.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_9.index = pd.to_datetime(df_9.date)

df_10 = pd.read_csv('10.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_10.index = pd.to_datetime(df_10.date)

df_11 = pd.read_csv('11.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_11.index = pd.to_datetime(df_11.date)

df_12 = pd.read_csv('12.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_12.index = pd.to_datetime(df_12.date)

df_13 = pd.read_csv('13.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_13.index = pd.to_datetime(df_13.date)

df_14 = pd.read_csv('14.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_14.index = pd.to_datetime(df_14.date)

df_15 = pd.read_csv('15.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_15.index = pd.to_datetime(df_15.date)

df_16 = pd.read_csv('16.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_16.index = pd.to_datetime(df_16.date)

df_17 = pd.read_csv('17.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_17.index = pd.to_datetime(df_17.date)

df_18 = pd.read_csv('18.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_18.index = pd.to_datetime(df_18.date)

df_19 = pd.read_csv('19.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_19.index = pd.to_datetime(df_19.date)

df_20 = pd.read_csv('20.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_20.index = pd.to_datetime(df_20.date)

df_21 = pd.read_csv('21.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_21.index = pd.to_datetime(df_21.date)

df_22 = pd.read_csv('22.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_22.index = pd.to_datetime(df_22.date)

df_23 = pd.read_csv('23.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_23.index = pd.to_datetime(df_23.date)

df_24 = pd.read_csv('24.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_24.index = pd.to_datetime(df_24.date)

df_25 = pd.read_csv('25.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_25.index = pd.to_datetime(df_25.date)

df_26 = pd.read_csv('26.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_26.index = pd.to_datetime(df_26.date)

df_27 = pd.read_csv('27.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_27.index = pd.to_datetime(df_27.date)

df_28 = pd.read_csv('28.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_28.index = pd.to_datetime(df_28.date)

df_29 = pd.read_csv('29.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_29.index = pd.to_datetime(df_29.date)

df_30 = pd.read_csv('30.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_30.index = pd.to_datetime(df_30.date)

df_31 = pd.read_csv('31.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_31.index = pd.to_datetime(df_31.date)

df_32 = pd.read_csv('32.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_32.index = pd.to_datetime(df_32.date)

df_33 = pd.read_csv('33.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_33.index = pd.to_datetime(df_33.date)

df_34 = pd.read_csv('34.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_34.index = pd.to_datetime(df_34.date)

df_35 = pd.read_csv('35.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_35.index = pd.to_datetime(df_35.date)

df_36 = pd.read_csv('36.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_36.index = pd.to_datetime(df_36.date)

df_37 = pd.read_csv('37.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_37.index = pd.to_datetime(df_37.date)

df_38 = pd.read_csv('38.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_38.index = pd.to_datetime(df_38.date)

df_39 = pd.read_csv('39.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_39.index = pd.to_datetime(df_39.date)

df_40 = pd.read_csv('40.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_40.index = pd.to_datetime(df_40.date)

df_41 = pd.read_csv('41.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_41.index = pd.to_datetime(df_41.date)

df_42 = pd.read_csv('42.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_42.index = pd.to_datetime(df_42.date)

df_43 = pd.read_csv('43.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_43.index = pd.to_datetime(df_43.date)

df_44 = pd.read_csv('44.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_44.index = pd.to_datetime(df_44.date)

df_45 = pd.read_csv('45.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_45.index = pd.to_datetime(df_45.date)

df_46 = pd.read_csv('46.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_46.index = pd.to_datetime(df_46.date)

df_47 = pd.read_csv('47.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_47.index = pd.to_datetime(df_47.date)

df_48 = pd.read_csv('48.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_48.index = pd.to_datetime(df_48.date)

df_49 = pd.read_csv('49.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_49.index = pd.to_datetime(df_49.date)

df_50 = pd.read_csv('50.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_50.index = pd.to_datetime(df_50.date)

df_51 = pd.read_csv('51.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_51.index = pd.to_datetime(df_51.date)

df_52 = pd.read_csv('52.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_52.index = pd.to_datetime(df_52.date)

df_53 = pd.read_csv('53.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_53.index = pd.to_datetime(df_53.date)

df_54 = pd.read_csv('54.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_54.index = pd.to_datetime(df_54.date)

df_55 = pd.read_csv('55.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_55.index = pd.to_datetime(df_55.date)

df_56 = pd.read_csv('56.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_56.index = pd.to_datetime(df_56.date)

df_57 = pd.read_csv('57.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_57.index = pd.to_datetime(df_57.date)

df_58 = pd.read_csv('58.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_58.index = pd.to_datetime(df_58.date)

df_59 = pd.read_csv('59.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_59.index = pd.to_datetime(df_59.date)

df_60 = pd.read_csv('60.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_60.index = pd.to_datetime(df_60.date)

df_61 = pd.read_csv('61.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_61.index = pd.to_datetime(df_61.date)

df_62 = pd.read_csv('62.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_62.index = pd.to_datetime(df_62.date)

df_63 = pd.read_csv('63.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_63.index = pd.to_datetime(df_63.date)

df_64 = pd.read_csv('64.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_64.index = pd.to_datetime(df_64.date)

df_65 = pd.read_csv('65.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_65.index = pd.to_datetime(df_65.date)

df_66 = pd.read_csv('66.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_66.index = pd.to_datetime(df_66.date)

df_67 = pd.read_csv('67.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_67.index = pd.to_datetime(df_67.date)

df_68 = pd.read_csv('68.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_68.index = pd.to_datetime(df_68.date)

df_69 = pd.read_csv('69.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_69.index = pd.to_datetime(df_69.date)

df_70 = pd.read_csv('70.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_70.index = pd.to_datetime(df_70.date)

#D.Monto en un df todos los ficheros descargados antes en df por fichero
df_final = pd.concat([df_0,df_1,df_2,df_3,df_4,df_5,df_6,df_7,df_8,df_9,
                     df_10,df_11,df_12,df_13,df_14,df_15,df_16,df_17,df_18,df_19,
                     df_20,df_21,df_22,df_23,df_24,df_25,df_26,df_27,df_28,df_29,
                     df_30,df_31,df_32,df_33,df_34,df_35,df_36,df_37,df_38,df_39,
                     df_40,df_41,df_42,df_43,df_44,df_45,df_46,df_47,df_48,df_49,
                     df_50,df_51,df_52,df_53,df_54,df_55,df_56,df_57,df_58,df_59,
                     df_60,df_61,df_62,df_63,df_64,df_65,df_66,df_67,df_68,df_69,df_70])

#Estudio de df_final para eliminar fondos y dias
#Mejora #¿Con cuántos activos nos quedamos y por qué? 
#Punto M.1 Eliminar fondos que tienen muy pocos valores.

#propongo eliminar todos los fondos que tengan un numero de dias inferior al quantile 65%.
# Se eliminarian 126057 fondos de un total original de 193678 fondos
#He llegado a esta conclusion al analizar el resultado segun los siguiente
fondos_por_dias_cotizados=df_final.loc[:,['date','name']].groupby('name').count()
p2=[]
for i in np.arange(0, 1, 0.01):    
    p2.extend(list(fondos_por_dias_cotizados.quantile(q=i)))
p2_df = pd.DataFrame(p2,index=np.arange(0, 1, 0.01))
p2_df.plot()
plt.xlabel('quantiles de dias con fondos')
plt.ylabel('numero de fondos')


a= list(fondos_por_dias_cotizados.quantile(q=0.65))
fondos_a_eliminar= fondos_por_dias_cotizados.index[fondos_por_dias_cotizados.date <= a[0]]
salvar_fondos=set(list(fondos_por_dias_cotizados.index)).difference(set(list(fondos_a_eliminar)))
df_final_2=df_final[df_final.name.isin(salvar_fondos)]


print('Total fondos descargados de 0 a 70.csv es de ',fondos_por_dias_cotizados.shape)
print('Total fondos que se deben eliminar que tienen un solo dias cotizados ',fondos_a_eliminar.shape)
print('El nombre de los fondos a eliminar estan en la variable fondos_a_eliminar')
print('Total fondos que no eliminaria pq tiene muchos dias cotizados ',len(salvar_fondos))


#Mejora

#Punto M.2 Eliminar dias que tienen muy pocos valores.
# Respecto a la pregunta: Hay días en los que la mayoría de los activos no tienen cotización ¿qué hacemos?

# Si repito el mismo ejercicio que la celda anterior pero respecto a los dias con pocos fondos cotizados, entonces me sale
df_final_3 = df_final_2
df_final_3 = df_final_3 .rename(columns={'date': 'date_1'})
dias_con_valores=df_final_3.loc[:,['date_1','name']].groupby('date_1').count()
#p=dias_con_valores.name.sort_values(ascending=True)
#p.plot.hist()

p2=[]
for i in np.arange(0, 1, 0.01):    
    p2.extend(list(dias_con_valores.quantile(q=i)))
p2_df = pd.DataFrame(p2,index=np.arange(0, 1, 0.01))
p2_df.plot()
plt.xlabel('quantiles de dias con fondos')
plt.ylabel('numero de fondos')


# En este caso; como se ve en las graficas, se podria quitar los que no alcanzaran el quantil 20%.
# Con este valor, quito los dias que afectan a solo 344 fondos de los 57945 que me quedanban de 
# la primera mejor. Todavia me quedaria con 274 dias para estudio.

b= list(dias_con_valores.quantile(q=0.20))
dias_a_eliminar= dias_con_valores.index[dias_con_valores.name <= b[0]]
#print(dias_a_eliminar.shape)
# que me sale a eliminar 70 dias.
# Se que esto no lo deberia hacer si tubiera un buen ordenador ya que el profesor ha dicho varias veces de eliminar
# menos numero de dias posible y es mejor rellenarlos con el valor posterior o si no el anterior dando unas 
# rentabilidades a 0 en esos dias. Pero en este caso los elimino pq es un reto.

# Elimino las dias que tengan name como los que me han salido en dias_con_valores_eliminar
# Y me quedo con el df_final_3

#salvar_dias=set(list(dias_con_valores.index)).difference(set(list(dias_con_valores_eliminar)))
salvar_dias=set(list(dias_con_valores.index)).difference(set(list(dias_a_eliminar)))
len(salvar_dias)
df_final_3=df_final_3[df_final_3.date_1.isin(salvar_dias)]
df_final_3 = df_final_3 .rename(columns={'date_1': 'date'})

df_0 = df_final_3 # esta linea la tengo para no fastidiar el programa que me iba con solo df_0

#1.creo el df para empezar para guardar los close de los fondos
import datetime
# Un dia en clase se dijo que habia fondos que cotizaban los fines de semana. 
# Pero creo que serian los minimos. Asi que mantengo freq=B y no pongo 'D' = diario
dates = pd.date_range('2020-1-1', '2020-12-31', freq='B') 
df_act = pd.DataFrame(np.zeros((dates.shape[0])),index = dates)
df_act = df_act.iloc[:,1:df_act.shape[1]]#Elimino la primera columna de ceros. Asi solo eta el indice

#HOMOGENIZACION
#Los activos no tienen los mismos días cotizados, ¿cómo los homogeneizamos?
#Esto lo resuelvo con mejora 1 y 2 y con la forma de crear df_act


#2.miro cuantos fondos tiene el df con el que voy a trabajar 
n_e_df_final = list(set(df_0.loc[:,'name']))
#len(n_e_df_final)
# y me salen 67621 fondos. Mas o menos lo esperado

#3 relleno el df por fondo y hago merge por dia 
# En el enunciado dice: El número de activos de cada cartera generada debe ser diferente... 
# saco un aleatorio que me diga que numero de fondos voy a analizar como sigue.
# Como hemos visto en clase que el max es 30; y ya es demasiado, que haga hasta 20 el
# numero de fondos a estudiar. Ya he visto testeando y testeando que mas de 12, la curva no sale
# He visto que con 2 y 3 fondos solo hace cosas raras. Asi que he puesto rangos de 4 a 12.

n_fondos = np.random.randint(4,12)

print('Numero de fondos es ',n_fondos)

# y los fondos que seran se eligen aleatoriamente asi:
fondos_posicion = list(np.random.randint(1,len(n_e_df_final),n_fondos))
fondos_estudio =[]
df_aux_2 = pd.DataFrame()

for i in fondos_posicion:
    #fondos_estudio.append(n_e_df_final[i])
    df_aux_2 = df_0[df_0.loc[:,'name'] == n_e_df_final[i]]
    df_act = df_act.merge(df_aux_2.loc[:,'nav'], how='outer', left_index=True, right_index=True)
    df_act.rename(columns = {'nav':n_e_df_final[i]}, inplace = True)

#df_act.shape





# LIMPIEZA DE NANS SI HUBIERA

#4. miro los nan de los fondos
cuantos_nan = df_act.isna().sum()
menos_nan = min(df_act.isna().sum())
cuantos_nan_ord = cuantos_nan.sort_values()
#print(cuantos_nan)
#print(menos_nan)
#print(cuantos_nan_ord)
# me salen solo algunos nan en 6 fondos. Los pordria eliminar, pero como tambien tienen un gran numero de valores,
# pues los dejo y que se rellenen mas tarde con el fillna



#5  El cinco no es necesario si quito los nan en el df de trabajo

#6 dropna para eliminar cuando toda la fila en nan ya que hay fondos tan importantes que seguro que trabajaban
#todos los dias menos los festivos, pq me salia qu esolo 18 dias estaban de sobra 
df_act_2 = df_act.dropna(how='all')

#df_act_2

# RELLENAR LOS NAN QUE PARECE LOGUICOS QUE TENGAMOS
#7 Relleno los nan que falta poniendo el del dia siquiente (como primera opcion) o el del dia anterior
df_act_2 = df_act_2.fillna(method='ffill')
df_act_2 = df_act_2.fillna(method='bfill')


#AQUI TERMINAMOS LA HOMOGENIZACION Y COMPLETAR LOS NAN TENIENDO LAS CONCLUSIONES EN df_act_2
#df_act_2

#EMPEZAMOS EL PROGRAMA SEGUN LO INDICADO POR Reto Markowitz

#8.Calculamos la rentabilidad de los activos.
df_rent_act = np.log(df_act_2).diff() # como estan en los apuntes del profesor
df_rent_act = df_rent_act.iloc[1:,:] # le quito la primera fila como dice en apuntes de r
df_rent_act

#9. Calculamos la matriz de correlacion del df de rentabilidades de los activos 

corr_df = df_rent_act.corr()
corr_df.fillna(0, inplace=True) # aveces me ha salido un fondo sin dias que el corr era nan; cuando testeaba. Por si acaso, que me lo cambie a 0

#10. Calculamos la matriz de varianzas/covarianzas 
cov_df = df_rent_act.cov()
cov_df.fillna(0, inplace=True)



#11. Calculamos la rentabilidad diaria del periodo para cada activo: LN(precio final/ precio inicial)/nº de datos
rentabilidad = np.log(df_act_2.iloc[df_act_2.shape[0]-1,:]/df_act_2.iloc[0,:])/df_act_2.shape[0]  

#12 Sacamos la matriz de pesos para cada cartera
num_simulaciones = 50000 
print('Numero de simulaciones es ',num_simulaciones)

# Como se podria bajar el numero de simulacion?
# Los metodos estudiados para que las simulaciones sean mas efectivas hasta ahora serian:
# - Montecarlo
# - Bootstrapping simple
# - Mencionado en clase el Bootstrapping saltando entre periodos
# - Random porfolio
# Entiendo que al usar otro que no seal el Random, no seria necesiario usar 50000 simulaciones

# Usare el Random porfolio ahora. Pero voy a dejar el Montecarlo preparado para usarlo tambien si se quiere.


# El profesor ha pedido
#- No todos los activos pueden tener asignado un peso en la generación aleatoria
# ¿Cómo generamos los números aleatorios y cuantos generamos? 

#METODO RAMDOM PARA CALCULAR PESOS
# Veo dos metodos. Primero genero facilemnte todos los numero aleatorios y los cargo en df de pesos a la vez. 
# Y luego pongo ceros para los que me den en el segundo grupo de aleatorios que no los quiero. 
pesos_df = pd.DataFrame(np.random.uniform(low=0,high=100,size=(num_simulaciones,df_act_2.shape[1])))
pesos_df.columns = df_act_2.columns

ceros_por_simulacion = []

num_de_fondos = df_act_2.shape[1] 
ceros = 0
for j in range(0,num_simulaciones-1):
    ceros_por_simulacion = random.randint(0, num_de_fondos-1)
    # He visto que el programa hace las graficas mejor cuando no hago esta carga de ceros.
    # Eniendo que se deberia limitar el numero de fondos a los que cargado ceros en los pesos por simulacion.
    # Pero no me ha dado tiempo a optimizar este valor
    for i in range(ceros_por_simulacion):
        a = random.randint(0, num_de_fondos-1)
        pesos_df.iloc[j,a] = 0 ############################################################################################
        ceros=ceros+1
porcentaje_ceros = (ceros/(pesos_df.shape[0]*pesos_df.shape[1]))*100
print('Numero de ceros puestos es en %: ',porcentaje_ceros)

#Y una segunda forma es linealmente. Es decir que primero se busca la poscion como antes bscaba la posicion 
# de los ceros; y luego cargo el valor np.random.uniform(low=0,high=100.5)

# Si  calculo los pesos por el METODO MONTECARLO




# Esta parte de generar pesos se podria mejorar el rendimiento con multiprocessing dividiendo el df pesos_df.
#Guillermo me HA dicho por email que Python no va muy bien con el multipocesing pero se podria intentar con mas tiempo.
# Seria algo asi
#import multiprocessing as mp 
#pool = mp.Pool(mp.cpu_count()-1)
#def funct_to_paral(param): 
    # aqui seria lo que tengo programado en esta celda arriba
#    return pesos_df
#pesos_df = pool.map(funct_to_paral, pesos_df) 
#print(results)

#13. Hacemos que la suma de todos los pesos por simulacion (por fila) sumen 1
#Normalizamos para que sume 1, para cada día
pesos_df = pesos_df.div(pesos_df.sum(1), axis=0) 


#14. Calculamos la rentabilidad de la cartera en funcion de los pesos
aux = pesos_df.T.mul(rentabilidad, axis = 0)

#15.Sumamos las filas para sacar rentabilidad de cada cartera.
#matriz_intermedia = aux.T
#matriz_intermedia.columns = df_act_2.columns
#rentabilidad_carteras = matriz_intermedia.sum(axis=1)
rentabilidad_carteras=aux.sum(axis=0)

#16. Calculamos el riesgo de la cartera (desviación), en función de los pesos.
# Generamos un vector donde guardaremos el riesgo de cada cartera.
riesgo_carteras = [] 
# Ahora multiplicamos la matriz de var/covar por cada fila de la matriz de pesos.
matriz_intermedia = pesos_df.iloc[0:num_simulaciones,]@cov_df
# Ahora multiplicamos cada fila de la matriz intermedia * cada fila de la matriz pesos y el rdo lo elevamos a 0.5. 
  # Ojo, la multiplicación es matricial de dos vectores.
matriz_intermedia_2 = matriz_intermedia * pesos_df
riesgo_carteras = matriz_intermedia_2.sum(axis=1)
riesgo_carteras = riesgo_carteras**0.5

#17. calculamos la eficiencia de la cartera (pendiente), en función de los pesos.
#eficiencia_carteras = []
eficiencia_carteras =  rentabilidad_carteras/riesgo_carteras


#18 # Graficamos la frontera de Markowitz (riesgo y rentabilidad para cada vector de pesos)

data=pd.concat([rentabilidad_carteras,riesgo_carteras],axis=1)
data.columns=['rentabilidad_carteras','riesgo_carteras']
fig, ax = plt.subplots(figsize=(20,10)) 
plt.scatter(data['riesgo_carteras'], data['rentabilidad_carteras'], color='black')

#plt.set_title('Reto Markowitz, para num.activos ',n_fondos, 'y con num.simulaciones ',num_simulaciones)
titulo = 'Reto Markowitz, para num.activos', n_fondos, ',con num.simulaciones ',num_simulaciones,' y con un porcentaje de ceros de ',porcentaje_ceros,'%'
plt.title(titulo)
plt.grid(True,color = 'w',linestyle = ':')
plt.xlabel('riesgo_carteras')
plt.ylabel('rentabilidad_carteras')

data_riesgo_carteras_2d=round(data['riesgo_carteras'],4)
lista = set(data_riesgo_carteras_2d)
riesgo_lista=list()
rent_max_lista=list()

for i in range(1,len(lista)):
    riesgo = lista.pop()    
    riesgo_lista.append(riesgo)
    rent_max=max(data['rentabilidad_carteras'][data_riesgo_carteras_2d==riesgo])
    rent_max_lista.append(rent_max)

rent_max_series=pd.Series(rent_max_lista)
riesgo_lista_series=pd.Series(riesgo_lista)

data_2=pd.concat([rent_max_series,riesgo_lista_series],axis=1)
data_2.columns=['rent_max_series','riesgo_lista_series']

elimina=list()
for i in range(1,data_2.shape[0]-1):
    if data_2['rent_max_series'][i]>data_2['rent_max_series'][i-1]:
        elimina.append(i)
# Aveces este programita solo para dibujar bien los puntos de la curva de Markowitz me da error
# a que los valores de riesgo esten entre min_riesgo['riesgo_cartera'] y max_rentabilidad['riesgo_cartera']        
        

#try: 
data_2 = data_2[~(data_2.index.isin(elimina))]
plt.scatter(data_2['riesgo_lista_series'], data_2['rent_max_series'], color='y')
#except AttributeError:
#    print('Esta vez no se ha cargado la curva de Markowitz') 

# 19 Localizamos la cartera con mayor rentabilidad, menor riesgo y mayor eficiencia
pesos_df.insert(pesos_df.shape[1],"rentabilidad_cartera",rentabilidad_carteras,True)
pesos_df.insert(pesos_df.shape[1],"riesgo_cartera",riesgo_carteras,True)
pesos_df.insert(pesos_df.shape[1],"eficiencia_cartera",eficiencia_carteras,True)

max_rentabilidad = pesos_df[pesos_df.loc[:,'rentabilidad_cartera'] == max(pesos_df.loc[:,'rentabilidad_cartera'])]
min_riesgo = pesos_df[pesos_df.loc[:,'riesgo_cartera'] == min(pesos_df.loc[:,'riesgo_cartera'])]
max_eficiencia = pesos_df[pesos_df.loc[:,'eficiencia_cartera'] == max(pesos_df.loc[:,'eficiencia_cartera'])]

plt.scatter(max_rentabilidad['riesgo_cartera'], max_rentabilidad['rentabilidad_cartera'], color='r')
plt.scatter(min_riesgo['riesgo_cartera'], min_riesgo['rentabilidad_cartera'], color='r')




print("This time is being calculated")
end = time.process_time()
print(end - start)
# Out:
# Total fondos descargados de 0 a 70.csv es de  (193678, 1)
# Total fondos que se deben eliminar que tienen un solo dias cotizados  (126057,)
# El nombre de los fondos a eliminar estan en la variable fondos_a_eliminar
# Total fondos que no eliminaria pq tiene muchos dias cotizados  67621
# Numero de fondos es  10
# Numero de simulaciones es  50000
# Numero de ceros puestos es en %:  45.1398
# This time is being calculated
# 62.90625

# %% [markdown]
# SECCION 3

# %%
#Y AQUI AL FINAL EL PROGRAMA COMPLETO PARA VER EL TIEMPO TOTAL DE EJECUCION
#(He quitado la parte de poner ceros en el pesos_df pq esta parte esta solo para demostrar que el programa vale para
# todos los fondos (unos 65000) con 50000 simulaciones)

import time
start = time.process_time()

#PREPARO LAS BASES DEL PROGRAMA
#A. Import the os module
import os
os.getcwd()
# Change the current working directory
os.chdir('C:\\Users\\Lenovo\\anaconda3\\Programando')


os.getcwd()

#B. Cargar toda las librerias que estoy usando
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from datetime import timedelta
import random
from datetime import datetime

#C.Descargo todos los ficheros csv con fondos
df_0 = pd.read_csv('0.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_0.index = pd.to_datetime(df_0.date)

df_1 = pd.read_csv('1.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_1.index = pd.to_datetime(df_1.date)

df_2 = pd.read_csv('2.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_2.index = pd.to_datetime(df_2.date)

df_3 = pd.read_csv('3.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_3.index = pd.to_datetime(df_3.date)

df_4 = pd.read_csv('4.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_4.index = pd.to_datetime(df_4.date)

df_5 = pd.read_csv('5.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_5.index = pd.to_datetime(df_5.date)

df_6 = pd.read_csv('6.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_6.index = pd.to_datetime(df_6.date)

df_7 = pd.read_csv('7.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_7.index = pd.to_datetime(df_7.date)

df_8 = pd.read_csv('8.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_8.index = pd.to_datetime(df_8.date)

df_9 = pd.read_csv('9.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_9.index = pd.to_datetime(df_9.date)

df_10 = pd.read_csv('10.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_10.index = pd.to_datetime(df_10.date)

df_11 = pd.read_csv('11.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_11.index = pd.to_datetime(df_11.date)

df_12 = pd.read_csv('12.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_12.index = pd.to_datetime(df_12.date)

df_13 = pd.read_csv('13.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_13.index = pd.to_datetime(df_13.date)

df_14 = pd.read_csv('14.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_14.index = pd.to_datetime(df_14.date)

df_15 = pd.read_csv('15.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_15.index = pd.to_datetime(df_15.date)

df_16 = pd.read_csv('16.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_16.index = pd.to_datetime(df_16.date)

df_17 = pd.read_csv('17.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_17.index = pd.to_datetime(df_17.date)

df_18 = pd.read_csv('18.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_18.index = pd.to_datetime(df_18.date)

df_19 = pd.read_csv('19.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_19.index = pd.to_datetime(df_19.date)

df_20 = pd.read_csv('20.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_20.index = pd.to_datetime(df_20.date)

df_21 = pd.read_csv('21.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_21.index = pd.to_datetime(df_21.date)

df_22 = pd.read_csv('22.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_22.index = pd.to_datetime(df_22.date)

df_23 = pd.read_csv('23.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_23.index = pd.to_datetime(df_23.date)

df_24 = pd.read_csv('24.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_24.index = pd.to_datetime(df_24.date)

df_25 = pd.read_csv('25.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_25.index = pd.to_datetime(df_25.date)

df_26 = pd.read_csv('26.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_26.index = pd.to_datetime(df_26.date)

df_27 = pd.read_csv('27.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_27.index = pd.to_datetime(df_27.date)

df_28 = pd.read_csv('28.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_28.index = pd.to_datetime(df_28.date)

df_29 = pd.read_csv('29.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_29.index = pd.to_datetime(df_29.date)

df_30 = pd.read_csv('30.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_30.index = pd.to_datetime(df_30.date)

df_31 = pd.read_csv('31.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_31.index = pd.to_datetime(df_31.date)

df_32 = pd.read_csv('32.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_32.index = pd.to_datetime(df_32.date)

df_33 = pd.read_csv('33.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_33.index = pd.to_datetime(df_33.date)

df_34 = pd.read_csv('34.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_34.index = pd.to_datetime(df_34.date)

df_35 = pd.read_csv('35.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_35.index = pd.to_datetime(df_35.date)

df_36 = pd.read_csv('36.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_36.index = pd.to_datetime(df_36.date)

df_37 = pd.read_csv('37.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_37.index = pd.to_datetime(df_37.date)

df_38 = pd.read_csv('38.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_38.index = pd.to_datetime(df_38.date)

df_39 = pd.read_csv('39.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_39.index = pd.to_datetime(df_39.date)

df_40 = pd.read_csv('40.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_40.index = pd.to_datetime(df_40.date)

df_41 = pd.read_csv('41.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_41.index = pd.to_datetime(df_41.date)

df_42 = pd.read_csv('42.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_42.index = pd.to_datetime(df_42.date)

df_43 = pd.read_csv('43.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_43.index = pd.to_datetime(df_43.date)

df_44 = pd.read_csv('44.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_44.index = pd.to_datetime(df_44.date)

df_45 = pd.read_csv('45.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_45.index = pd.to_datetime(df_45.date)

df_46 = pd.read_csv('46.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_46.index = pd.to_datetime(df_46.date)

df_47 = pd.read_csv('47.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_47.index = pd.to_datetime(df_47.date)

df_48 = pd.read_csv('48.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_48.index = pd.to_datetime(df_48.date)

df_49 = pd.read_csv('49.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_49.index = pd.to_datetime(df_49.date)

df_50 = pd.read_csv('50.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_50.index = pd.to_datetime(df_50.date)

df_51 = pd.read_csv('51.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_51.index = pd.to_datetime(df_51.date)

df_52 = pd.read_csv('52.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_52.index = pd.to_datetime(df_52.date)

df_53 = pd.read_csv('53.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_53.index = pd.to_datetime(df_53.date)

df_54 = pd.read_csv('54.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_54.index = pd.to_datetime(df_54.date)

df_55 = pd.read_csv('55.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_55.index = pd.to_datetime(df_55.date)

df_56 = pd.read_csv('56.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_56.index = pd.to_datetime(df_56.date)

df_57 = pd.read_csv('57.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_57.index = pd.to_datetime(df_57.date)

df_58 = pd.read_csv('58.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_58.index = pd.to_datetime(df_58.date)

df_59 = pd.read_csv('59.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_59.index = pd.to_datetime(df_59.date)

df_60 = pd.read_csv('60.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_60.index = pd.to_datetime(df_60.date)

df_61 = pd.read_csv('61.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_61.index = pd.to_datetime(df_61.date)

df_62 = pd.read_csv('62.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_62.index = pd.to_datetime(df_62.date)

df_63 = pd.read_csv('63.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_63.index = pd.to_datetime(df_63.date)

df_64 = pd.read_csv('64.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_64.index = pd.to_datetime(df_64.date)

df_65 = pd.read_csv('65.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_65.index = pd.to_datetime(df_65.date)

df_66 = pd.read_csv('66.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_66.index = pd.to_datetime(df_66.date)

df_67 = pd.read_csv('67.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_67.index = pd.to_datetime(df_67.date)

df_68 = pd.read_csv('68.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_68.index = pd.to_datetime(df_68.date)

df_69 = pd.read_csv('69.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_69.index = pd.to_datetime(df_69.date)

df_70 = pd.read_csv('70.csv', 
                    header = 0,
                    index_col = 'Unnamed: 0')
df_70.index = pd.to_datetime(df_70.date)

#D.Monto en un df todos los ficheros descargados antes en df por fichero
df_final = pd.concat([df_0,df_1,df_2,df_3,df_4,df_5,df_6,df_7,df_8,df_9,
                     df_10,df_11,df_12,df_13,df_14,df_15,df_16,df_17,df_18,df_19,
                     df_20,df_21,df_22,df_23,df_24,df_25,df_26,df_27,df_28,df_29,
                     df_30,df_31,df_32,df_33,df_34,df_35,df_36,df_37,df_38,df_39,
                     df_40,df_41,df_42,df_43,df_44,df_45,df_46,df_47,df_48,df_49,
                     df_50,df_51,df_52,df_53,df_54,df_55,df_56,df_57,df_58,df_59,
                     df_60,df_61,df_62,df_63,df_64,df_65,df_66,df_67,df_68,df_69,df_70])

#Estudio de df_final para eliminar fondos y dias
#Mejora #¿Con cuántos activos nos quedamos y por qué? 
#Punto M.1 Eliminar fondos que tienen muy pocos valores.

#propongo eliminar todos los fondos que tengan un numero de dias inferior al quantile 65%.
# Se eliminarian 126057 fondos de un total original de 193678 fondos
#He llegado a esta conclusion al analizar el resultado segun los siguiente
fondos_por_dias_cotizados=df_final.loc[:,['date','name']].groupby('name').count()
p2=[]
for i in np.arange(0, 1, 0.01):    
    p2.extend(list(fondos_por_dias_cotizados.quantile(q=i)))
p2_df = pd.DataFrame(p2,index=np.arange(0, 1, 0.01))
p2_df.plot()
plt.xlabel('quantiles de dias con fondos')
plt.ylabel('numero de fondos')


a= list(fondos_por_dias_cotizados.quantile(q=0.65))
fondos_a_eliminar= fondos_por_dias_cotizados.index[fondos_por_dias_cotizados.date <= a[0]]
salvar_fondos=set(list(fondos_por_dias_cotizados.index)).difference(set(list(fondos_a_eliminar)))
df_final_2=df_final[df_final.name.isin(salvar_fondos)]


print('Total fondos descargados de 0 a 70.csv es de ',fondos_por_dias_cotizados.shape)
print('Total fondos que se deben eliminar que tienen un solo dias cotizados ',fondos_a_eliminar.shape)
print('El nombre de los fondos a eliminar estan en la variable fondos_a_eliminar')
print('Total fondos que no eliminaria pq tiene muchos dias cotizados ',len(salvar_fondos))


#Mejora

#Punto M.2 Eliminar dias que tienen muy pocos valores.
# Respecto a la pregunta: Hay días en los que la mayoría de los activos no tienen cotización ¿qué hacemos?

# Si repito el mismo ejercicio que la celda anterior pero respecto a los dias con pocos fondos cotizados, entonces me sale
df_final_3 = df_final_2
df_final_3 = df_final_3 .rename(columns={'date': 'date_1'})
dias_con_valores=df_final_3.loc[:,['date_1','name']].groupby('date_1').count()
#p=dias_con_valores.name.sort_values(ascending=True)
#p.plot.hist()

p2=[]
for i in np.arange(0, 1, 0.01):    
    p2.extend(list(dias_con_valores.quantile(q=i)))
p2_df = pd.DataFrame(p2,index=np.arange(0, 1, 0.01))
p2_df.plot()
plt.xlabel('quantiles de dias con fondos')
plt.ylabel('numero de fondos')


# En este caso; como se ve en las graficas, se podria quitar los que no alcanzaran el quantil 20%.
# Con este valor, quito los dias que afectan a solo 344 fondos de los 57945 que me quedanban de 
# la primera mejor. Todavia me quedaria con 274 dias para estudio.

b= list(dias_con_valores.quantile(q=0.20))
dias_a_eliminar= dias_con_valores.index[dias_con_valores.name <= b[0]]
#print(dias_a_eliminar.shape)
# que me sale a eliminar 70 dias.
# Se que esto no lo deberia hacer si tubiera un buen ordenador ya que el profesor ha dicho varias veces de eliminar
# menos numero de dias posible y es mejor rellenarlos con el valor posterior o si no el anterior dando unas 
# rentabilidades a 0 en esos dias. Pero en este caso los elimino pq es un reto.

# Elimino las dias que tengan name como los que me han salido en dias_con_valores_eliminar
# Y me quedo con el df_final_3

#salvar_dias=set(list(dias_con_valores.index)).difference(set(list(dias_con_valores_eliminar)))
salvar_dias=set(list(dias_con_valores.index)).difference(set(list(dias_a_eliminar)))
len(salvar_dias)
df_final_3=df_final_3[df_final_3.date_1.isin(salvar_dias)]
df_final_3 = df_final_3 .rename(columns={'date_1': 'date'})

df_0 = df_final_3 # esta linea la tengo para no fastidiar el programa que me iba con solo df_0

#1.creo el df para empezar para guardar los close de los fondos
import datetime
# Un dia en clase se dijo que habia fondos que cotizaban los fines de semana. 
# Pero creo que serian los minimos. Asi que mantengo freq=B y no pongo 'D' = diario
dates = pd.date_range('2020-1-1', '2020-12-31', freq='B') 
df_act = pd.DataFrame(np.zeros((dates.shape[0])),index = dates)
df_act = df_act.iloc[:,1:df_act.shape[1]]#Elimino la primera columna de ceros. Asi solo eta el indice

#HOMOGENIZACION
#Los activos no tienen los mismos días cotizados, ¿cómo los homogeneizamos?
#Esto lo resuelvo con mejora 1 y 2 y con la forma de crear df_act


#2.miro cuantos fondos tiene el df con el que voy a trabajar 
n_e_df_final = list(set(df_0.loc[:,'name']))
#len(n_e_df_final)
# y me salen 67621 fondos. Mas o menos lo esperado

#3 relleno el df por fondo y hago merge por dia 
# En el enunciado dice: El número de activos de cada cartera generada debe ser diferente... 
# saco un aleatorio que me diga que numero de fondos voy a analizar como sigue.
# Como hemos visto en clase que el max es 30; y ya es demasiado, que haga hasta 20 el
# numero de fondos a estudiar. Ya he visto testeando y testeando que mas de 12, la curva no sale
# He visto que con 2 y 3 fondos solo hace cosas raras. Asi que he puesto rangos de 4 a 12.

fondos_por_dias_cotizados=df_0.loc[:,['date','name']].groupby('name').count()
n_fondos = fondos_por_dias_cotizados.shape[0]######################AQUI PONGO NUMERO DE FONDOS TODOS LOS DISPONBLES
#n_fondos = np.random.randint(4,12)
print('Numero de fondos es ',n_fondos)

# y los fondos que seran se eligen aleatoriamente asi:
fondos_posicion = list(np.random.randint(1,len(n_e_df_final),n_fondos))
#fondos_estudio =[]
#df_aux_2 = pd.DataFrame()

for i in fondos_posicion:
    #fondos_estudio.append(n_e_df_final[i])
    df_aux_2 = df_0[df_0.loc[:,'name'] == n_e_df_final[i]]
    df_act = df_act.merge(df_aux_2.loc[:,'nav'], how='outer', left_index=True, right_index=True)
    df_act.rename(columns = {'nav':n_e_df_final[i]}, inplace = True)

#df_act.shape





# LIMPIEZA DE NANS SI HUBIERA

#4. miro los nan de los fondos
cuantos_nan = df_act.isna().sum()
menos_nan = min(df_act.isna().sum())
cuantos_nan_ord = cuantos_nan.sort_values()
#print(cuantos_nan)
#print(menos_nan)
#print(cuantos_nan_ord)
# me salen solo algunos nan en 6 fondos. Los pordria eliminar, pero como tambien tienen un gran numero de valores,
# pues los dejo y que se rellenen mas tarde con el fillna



#5  El cinco no es necesario si quito los nan en el df de trabajo

#6 dropna para eliminar cuando toda la fila en nan ya que hay fondos tan importantes que seguro que trabajaban
#todos los dias menos los festivos, pq me salia qu esolo 18 dias estaban de sobra 
df_act_2 = df_act.dropna(how='all')

#df_act_2

# RELLENAR LOS NAN QUE PARECE LOGUICOS QUE TENGAMOS
#7 Relleno los nan que falta poniendo el del dia siquiente (como primera opcion) o el del dia anterior
df_act_2 = df_act_2.fillna(method='ffill')
df_act_2 = df_act_2.fillna(method='bfill')


#AQUI TERMINAMOS LA HOMOGENIZACION Y COMPLETAR LOS NAN TENIENDO LAS CONCLUSIONES EN df_act_2
#df_act_2

#EMPEZAMOS EL PROGRAMA SEGUN LO INDICADO POR Reto Markowitz

#8.Calculamos la rentabilidad de los activos.
df_rent_act = np.log(df_act_2).diff() # como estan en los apuntes del profesor
df_rent_act = df_rent_act.iloc[1:,:] # le quito la primera fila como dice en apuntes de r
df_rent_act

#9. Calculamos la matriz de correlacion del df de rentabilidades de los activos 

corr_df = df_rent_act.corr()
corr_df.fillna(0, inplace=True) # aveces me ha salido un fondo sin dias que el corr era nan; cuando testeaba. Por si acaso, que me lo cambie a 0

#10. Calculamos la matriz de varianzas/covarianzas 
cov_df = df_rent_act.cov()
cov_df.fillna(0, inplace=True)



#11. Calculamos la rentabilidad diaria del periodo para cada activo: LN(precio final/ precio inicial)/nº de datos
rentabilidad = np.log(df_act_2.iloc[df_act_2.shape[0]-1,:]/df_act_2.iloc[0,:])/df_act_2.shape[0]  

#12 Sacamos la matriz de pesos para cada cartera
num_simulaciones = 50000 
print('Numero de simulaciones es ',num_simulaciones)

# Como se podria bajar el numero de simulacion?
# Los metodos estudiados para que las simulaciones sean mas efectivas hasta ahora serian:
# - Montecarlo
# - Bootstrapping simple
# - Mencionado en clase el Bootstrapping saltando entre periodos
# - Random porfolio
# Entiendo que al usar otro que no sea el Random, no seria necesiario usar 50000 simulaciones

# Usare el Random porfolio ahora. Pero voy a dejar el Montecarlo preparado para usarlo tambien si se quiere.


# El profesor ha pedido
#- No todos los activos pueden tener asignado un peso en la generación aleatoria
# ¿Cómo generamos los números aleatorios y cuantos generamos? 

#METODO RAMDOM PARA CALCULAR PESOS
# Veo dos metodos. Primero genero facilemnte todos los numero aleatorios y los cargo en df de pesos a la vez. 
# Y luego pongo ceros para los que me den en el segundo grupo de aleatorios que no los quiero. 
pesos_df = pd.DataFrame(np.random.uniform(low=0,high=100,size=(num_simulaciones,df_act_2.shape[1])))
pesos_df.columns = df_act_2.columns

ceros_por_simulacion = []

num_de_fondos = fondos_por_dias_cotizados.shape[0] ######################AQUI PONGO NUMERO DE FONDOS TODOS LOS DISPONBLES
ceros = 0
for j in range(0,num_simulaciones-1):
    ceros_por_simulacion = random.randint(0, num_de_fondos-1)
    # He visto que el programa hace las graficas mejor cuando no hago esta carga de ceros.
    # Eniendo que se deberia limitar el numero de fondos a los que cargado ceros en los pesos por simulacion.
    # Pero no me ha dado tiempo a optimizar este valor
    for i in range(ceros_por_simulacion):
        a = random.randint(0, num_de_fondos-1)
        pesos_df.iloc[j,a] = 0 ############################################################################################
        ceros=ceros+1
porcentaje_ceros = (ceros/(pesos_df.shape[0]*pesos_df.shape[1]))*100
print('Numero de ceros puestos es en %: ',porcentaje_ceros)

#Y una segunda forma es linealmente. Es decir que primero se busca la poscion como antes bscaba la posicion 
# de los ceros; y luego cargo el valor np.random.uniform(low=0,high=100.5)

# Si  calculo los pesos por el METODO MONTECARLO




# Esta parte de generar pesos se podria mejorar el rendimiento con multiprocessing dividiendo el df pesos_df.
#Guillermo me HA dicho por email que Python no va muy bien con el multipocesing pero se podria intentar con mas tiempo.
# Seria algo asi
#import multiprocessing as mp 
#pool = mp.Pool(mp.cpu_count()-1)
#def funct_to_paral(param): 
    # aqui seria lo que tengo programado en esta celda arriba
#    return pesos_df
#pesos_df = pool.map(funct_to_paral, pesos_df) 
#print(results)

#13. Hacemos que la suma de todos los pesos por simulacion (por fila) sumen 1
#Normalizamos para que sume 1, para cada día
pesos_df = pesos_df.div(pesos_df.sum(1), axis=0) 


#14. Calculamos la rentabilidad de la cartera en funcion de los pesos
aux = pesos_df.T.mul(rentabilidad, axis = 0)

#15.Sumamos las filas para sacar rentabilidad de cada cartera.
#matriz_intermedia = aux.T
#matriz_intermedia.columns = df_act_2.columns
#rentabilidad_carteras = matriz_intermedia.sum(axis=1)
rentabilidad_carteras=aux.sum(axis=0)

#16. Calculamos el riesgo de la cartera (desviación), en función de los pesos.
# Generamos un vector donde guardaremos el riesgo de cada cartera.
riesgo_carteras = [] 
# Ahora multiplicamos la matriz de var/covar por cada fila de la matriz de pesos.
matriz_intermedia = pesos_df.iloc[0:num_simulaciones,]@cov_df
# Ahora multiplicamos cada fila de la matriz intermedia * cada fila de la matriz pesos y el rdo lo elevamos a 0.5. 
  # Ojo, la multiplicación es matricial de dos vectores.
matriz_intermedia_2 = matriz_intermedia * pesos_df
riesgo_carteras = matriz_intermedia_2.sum(axis=1)
riesgo_carteras = riesgo_carteras**0.5

#17. calculamos la eficiencia de la cartera (pendiente), en función de los pesos.
#eficiencia_carteras = []
eficiencia_carteras =  rentabilidad_carteras/riesgo_carteras


#18 # Graficamos la frontera de Markowitz (riesgo y rentabilidad para cada vector de pesos)

data=pd.concat([rentabilidad_carteras,riesgo_carteras],axis=1)
data.columns=['rentabilidad_carteras','riesgo_carteras']
fig, ax = plt.subplots(figsize=(20,10)) 
plt.scatter(data['riesgo_carteras'], data['rentabilidad_carteras'], color='black')

#plt.set_title('Reto Markowitz, para num.activos ',n_fondos, 'y con num.simulaciones ',num_simulaciones)
titulo = 'Reto Markowitz, para num.activos', n_fondos, ',con num.simulaciones ',num_simulaciones,' y con un porcentaje de ceros de ',porcentaje_ceros,'%'
#titulo = 'Reto Markowitz, para num.activos', n_fondos, ',con num.simulaciones ',num_simulaciones
plt.title(titulo)
plt.grid(True,color = 'w',linestyle = ':')
plt.xlabel('riesgo_carteras')
plt.ylabel('rentabilidad_carteras')

data_riesgo_carteras_2d=round(data['riesgo_carteras'],4)
lista = set(data_riesgo_carteras_2d)
riesgo_lista=list()
rent_max_lista=list()

for i in range(1,len(lista)):
    riesgo = lista.pop()    
    riesgo_lista.append(riesgo)
    rent_max=max(data['rentabilidad_carteras'][data_riesgo_carteras_2d==riesgo])
    rent_max_lista.append(rent_max)

rent_max_series=pd.Series(rent_max_lista)
riesgo_lista_series=pd.Series(riesgo_lista)

data_2=pd.concat([rent_max_series,riesgo_lista_series],axis=1)
data_2.columns=['rent_max_series','riesgo_lista_series']

elimina=list()
for i in range(1,data_2.shape[0]-1):
    if data_2['rent_max_series'][i]>data_2['rent_max_series'][i-1]:
        elimina.append(i)
# Aveces este programita solo para dibujar bien los puntos de la curva de Markowitz me da error
# a que los valores de riesgo esten entre min_riesgo['riesgo_cartera'] y max_rentabilidad['riesgo_cartera']        
        

#try: 
data_2 = data_2[~(data_2.index.isin(elimina))]
plt.scatter(data_2['riesgo_lista_series'], data_2['rent_max_series'], color='y')
#except AttributeError:
#    print('Esta vez no se ha cargado la curva de Markowitz') 

# 19 Localizamos la cartera con mayor rentabilidad, menor riesgo y mayor eficiencia
pesos_df.insert(pesos_df.shape[1],"rentabilidad_cartera",rentabilidad_carteras,True)
pesos_df.insert(pesos_df.shape[1],"riesgo_cartera",riesgo_carteras,True)
pesos_df.insert(pesos_df.shape[1],"eficiencia_cartera",eficiencia_carteras,True)

max_rentabilidad = pesos_df[pesos_df.loc[:,'rentabilidad_cartera'] == max(pesos_df.loc[:,'rentabilidad_cartera'])]
min_riesgo = pesos_df[pesos_df.loc[:,'riesgo_cartera'] == min(pesos_df.loc[:,'riesgo_cartera'])]
max_eficiencia = pesos_df[pesos_df.loc[:,'eficiencia_cartera'] == max(pesos_df.loc[:,'eficiencia_cartera'])]

plt.scatter(max_rentabilidad['riesgo_cartera'], max_rentabilidad['rentabilidad_cartera'], color='r')
plt.scatter(min_riesgo['riesgo_cartera'], min_riesgo['rentabilidad_cartera'], color='r')




print("This time is being calculated")
end = time.process_time()
print(end - start)
# Out:
# Total fondos descargados de 0 a 70.csv es de  (193678, 1)
# Total fondos que se deben eliminar que tienen un solo dias cotizados  (126057,)
# El nombre de los fondos a eliminar estan en la variable fondos_a_eliminar
# Total fondos que no eliminaria pq tiene muchos dias cotizados  67621
# Numero de fondos es  67621
